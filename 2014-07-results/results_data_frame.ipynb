# %% [markdown]
# # Results DataFrame

# %%
import benchmark_analysis_utils as bau
df = bau.load_results_file("results_1405803619.csv").sort()

# %%
df
# Out:
#                                                          id  compress  decompress  dc_no_cache       ratio
# size  storage   complexity codec                level
# large ephemeral arange     bloscpack_blosclz    1      1382  0.195354    0.072230     0.087685    7.316364
#                                                 3      1084  0.094674    0.069611     0.073262   34.611860
#                                                 5      1140  0.083503    0.069971     0.072332   57.213946
#                                                 7       533  0.076434    0.070462     0.073212  113.589448
#                                                 9      1968  0.086598    0.072942     0.075012  136.475047
#                            bloscpack_lz4        1       161  0.093587    0.072790     0.076385   35.358830
#                                                 3       628  0.096648    0.073290     0.076742   35.358830
# ...
