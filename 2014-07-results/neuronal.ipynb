# %% [markdown]
# # Neuronal

# %%
import benchmark_analysis_utils as bau
df = bau.load_results_file("results_1405803619.csv").sort()

# %% [markdown]
# ## Small

# %%
df.loc[('small', 'esb', 'neuronal')].sort('compress')['compress'].plot(kind='barh', figsize=(15,40))

# %% [markdown]
# * bloscpack_lz4hc, 9 seems slow here

# %%
df.loc[('small', 'esb', 'neuronal')].sort('decompress')['decompress'].plot(kind='barh', figsize=(15,40))

# %% [markdown]
# * Hard to beat NPY but blosclz can do it
# * bloscpack_lz4hc, 9 doesn't do badly at all

# %%
df.loc[('small', 'esb', 'neuronal')].sort('dc_no_cache')['dc_no_cache'].plot(kind='barh', figsize=(15,40))

# %% [markdown]
# * On a cold cache, things look a bit better, but due to dataset size, NPY can still compete

# %%
df.loc[('small', 'esb', 'neuronal')].sort('ratio')['ratio'].plot(kind='barh', figsize=(15,40))

# %% [markdown]
# * Dataset has higher complexity, ratio of 2.5 is good

# %% [markdown]
# ## Large

# %%
df.loc[('large', 'esb', 'neuronal')].sort('compress')['compress'].plot(kind='barh', figsize=(15,40))

# %% [markdown]
# * bloscpack_lz4hc and zfile continue to suck

# %%
df.loc[('large', 'esb', 'neuronal')].sort('decompress')['decompress'].plot(kind='barh', figsize=(15,40))

# %% [markdown]
# * No surprises here, except that zfile is sloooow

# %%
df.loc[('large', 'esb', 'neuronal')].sort('dc_no_cache')['dc_no_cache'].plot(kind='barh', figsize=(15,40))

# %% [markdown]
# * Interestingly tables_zlib wins here, it's compression was also comparable to NPY, interesting

# %%
df.loc[('large', 'esb', 'neuronal')].sort('ratio')['ratio'].plot(kind='barh', figsize=(15,40))
