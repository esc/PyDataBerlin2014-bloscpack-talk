# %%
import pandas as pd

# %%
df = pd.read_csv('aggregate_with_ratio.csv').set_index('codec')

# %%
df.head()
# Out:
#          score
# codec
# npz_1     1634
# zfile_1   1903
# zfile_9   1975
# zfile_3   2009
# zfile_7   2024

# %%
df.tail()
# Out:
#                      score
# codec
# bloscpack_lz4hc_5     5978
# bloscpack_lz4hc_3     6005
# bloscpack_blosclz_7   6221
# bloscpack_lz4_9       6228
# bloscpack_lz4_7       6238

# %%
df.plot(kind='barh', figsize=(20,60))

# %%
df2 = pd.read_csv('aggregate_without_ratio.csv').set_index('codec')

# %%
df2.head()
# Out:
#                      score
# codec
# tables_zlib_7          623
# npz_1                  642
# tables_zlib_9          645
# tables_zlib_5          687
# tables_blosc_zlib_9    968

# %%
df2.tail()
# Out:
#                      score
# codec
# bloscpack_lz4_3       5342
# bloscpack_blosclz_5   5358
# bloscpack_lz4_1       5363
# bloscpack_lz4_7       5469
# bloscpack_lz4_5       5508

# %%
df.plot(kind='barh', figsize=(20,60))
